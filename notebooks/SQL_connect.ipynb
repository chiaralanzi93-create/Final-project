# %%
# Goal: import cleaned df into SQL or go to mySQL create a new schema - click on the name of the new schema - Table data import wizard to import a cleaned csv file.

#import pandas as pd
#import numpy as np
#import pymysql
#from sqlalchemy import create_engine
#import getpass  # To get the password without showing the input
#password = getpass.getpass("Please, input your SQL password: ")

# %%
#bd = "final_project" # name of new schema
#connection_string = 'mysql+pymysql://root:' + password + '@localhost/'+bd
#engine = create_engine(connection_string)
#engine

# %%
#Connect Table to new database
#df.to_sql(name='retail_fashion', con=engine, schema='final_project', if_exists='replace', index=False) # name of the new table in sql

# create a collection in python to populate the schema

# %%
# create table schemas in drawdb - export sql
# IN mysql create a new schema name - go to the newly created table double click ( import wizard) --> select the data content you want to import in that specific table making sure the format is utf-8 and the name of the columns match
